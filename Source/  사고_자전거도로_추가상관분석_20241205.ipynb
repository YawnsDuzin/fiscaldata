# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (17.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
# 나눔고딕 폰트 설정
plt.rc('font', family='NanumGothic')
# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import warnings
# 모든 경고 메시지 무시
warnings.filterwarnings('ignore')

# %%
# 나의 루트 경로 설정
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/최종/'

# %%
df_1 = pd.read_csv(path_dateset + '시군구_전처리_킥보드사고건수,전체사고건수,사고율/시군구_킥보드사고건수,전체사고건수,사고율_데이터셋.csv').reset_index(drop=True)
df_1.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율
# 0  강원특별자치도  강릉시           10     760  1.315789
# 1  강원특별자치도  고성군            1     111  0.900901
# 2  강원특별자치도  동해시            9     316  2.848101

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시도           228 non-null    object
#  1   시군구          228 non-null    object
#  2   개인형이동장치(PM)  228 non-null    int64
#  3   전체사고건수       228 non-null    int64
#  4   킥보드사고율       228 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.0+ KB

# %%
df_2 = pd.read_csv(path_dateset + '시군구_인구밀도(전처리).csv').reset_index(drop=True)
df_2.head(3)
# Out:
#         시도  시군구  총인구수(2023년)      면적(km²)  인구밀도(명/km²)
# 0  강원특별자치도  강릉시       209439  1040.827452       201.22
# 1  강원특별자치도  고성군        27305   660.766514        41.32
# 2  강원특별자치도  동해시        88625   180.307717       491.52

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시도           228 non-null    object
#  1   시군구          228 non-null    object
#  2   총인구수(2023년)  228 non-null    int64
#  3   면적(km²)      228 non-null    float64
#  4   인구밀도(명/km²)  228 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.0+ KB

# %%
df_3 = pd.read_csv(path_dateset + '전국자전거도로표준데이터(전처리)).csv').reset_index(drop=True)
df_3.head(3)
# Out:
#         시도  시군구  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로
# 0      강원도  인제군        2.60      0.0      0.0      0.0
# 1  강원특별자치도  강릉시      280.33      0.0      0.0      0.0
# 2  강원특별자치도  삼척시       34.50     12.0      0.0      2.4

# %%
df_3.loc[df_3['시군구'] == '서귀포시', '시군구'] = '제주특별자치도'

# %%
merged_df = df_1.merge(df_2, on=['시도', '시군구'], how='left')\
              .merge(df_3, on=['시도', '시군구'], how='left')
merged_df.head(5)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
# 3  강원특별자치도  삼척시            5     202  2.475248      62651.0  1187.836727
# 4  강원특별자치도  속초시            3     364  0.824176      82054.0   105.753667
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
# 3        52.74       34.50     12.0      0.0      2.4
# 4       775.90         NaN      NaN      NaN      NaN

# %%
merged_df.shape
# Out:
# (229, 12)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시도           229 non-null    object
#  1   시군구          229 non-null    object
#  2   개인형이동장치(PM)  229 non-null    int64
#  3   전체사고건수       229 non-null    int64
#  4   킥보드사고율       229 non-null    float64
#  5   총인구수(2023년)  228 non-null    float64
#  6   면적(km²)      228 non-null    float64
#  7   인구밀도(명/km²)  228 non-null    float64
#  8   자전거보행자겸용도로   96 non-null     float64
#  9   자전거우선도로      96 non-null     float64
#  10  자전거전용도로      96 non-null     float64
#  11  자전거전용차로      96 non-null     float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 21.6+ KB

# %%
merged_df.isnull().sum()
# Out:
# 시도               0
# 시군구              0
# 개인형이동장치(PM)      0
# 전체사고건수           0
# 킥보드사고율           0
# 총인구수(2023년)      1
# 면적(km²)          1
# 인구밀도(명/km²)      1
# 자전거보행자겸용도로     133
# 자전거우선도로        133
# 자전거전용도로        133
# 자전거전용차로        133
# dtype: int64

# %%
merged_df[merged_df['총인구수(2023년)'].isnull()]
# Out:
#         시도 시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)  면적(km²)  \
# 123  부산광역시  진구           15    1393  1.076813          NaN      NaN
#
#      인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로
# 123          NaN         NaN      NaN      NaN      NaN

# %%
merged_df[merged_df['시군구'] == '상주시']
# Out:
#       시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 74  경상북도  상주시           13     433  3.002309      93858.0  1254.706154
# 75  경상북도  상주시           13     433  3.002309      93858.0  1254.706154
#
#     인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로
# 74         74.8       59.23     2.65    108.0      2.9
# 75         74.8        0.00     0.00      4.8      0.0

# %%
merged_df.drop(index=75, inplace=True)

# %% [markdown]
# ---
# ## 피처 변수 생성

# %%
merged_df['개인형이동장치(PM)/총인구수(2023년)x100000'] = (merged_df['개인형이동장치(PM)'] / merged_df['총인구수(2023년)']) * 100000
merged_df['개인형이동장치(PM)/면적(km²)'] = merged_df['개인형이동장치(PM)'] / merged_df['면적(km²)']
merged_df['개인형이동장치(PM)/인구밀도(명/km²)'] = merged_df['개인형이동장치(PM)'] / merged_df['인구밀도(명/km²)']

# %%
merged_df.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  \
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
#
#    개인형이동장치(PM)/총인구수(2023년)x100000  개인형이동장치(PM)/면적(km²)  \
# 0                        4.774660             0.009608
# 1                        3.662333             0.001513
# 2                       10.155148             0.049915
#
#    개인형이동장치(PM)/인구밀도(명/km²)
# 0                 0.049697
# 1                 0.024201
# 2                 0.018311

# %%
merged_df.columns
# Out:
# Index(['시도', '시군구', '개인형이동장치(PM)', '전체사고건수', '킥보드사고율', '총인구수(2023년)',
#        '면적(km²)', '인구밀도(명/km²)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로',
#        '개인형이동장치(PM)/총인구수(2023년)x100000', '개인형이동장치(PM)/면적(km²)',
#        '개인형이동장치(PM)/인구밀도(명/km²)'],
#       dtype='object')

# %%
merged_df.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  \
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
#
#    개인형이동장치(PM)/총인구수(2023년)x100000  개인형이동장치(PM)/면적(km²)  \
# 0                        4.774660             0.009608
# 1                        3.662333             0.001513
# 2                       10.155148             0.049915
#
#    개인형이동장치(PM)/인구밀도(명/km²)
# 0                 0.049697
# 1                 0.024201
# 2                 0.018311

# %%
df_3 = pd.read_csv(path_dateset + '재정자주도_자립도_통합재정수지비율(병합).csv').reset_index(drop=True)
df_3.head(3)
# Out:
#     자치단체    자체수입   자주재원  자치단체 예산규모  재정자주도[당초]     시도  시군구  재정자립도[당초]  교부세비율  \
# 0  서울종로구  209783  80588     498962      58.19  서울특별시  종로구      42.04  16.15
# 1   서울중구  281447  25976     524792      58.58  서울특별시   중구      53.63   4.95
# 2  서울용산구  232426  75829     590040      52.24  서울특별시  용산구      39.39  12.85
#
#    국고보조금비율      세입      지출   순융자  통합재정규모  통합재정수지비율[당초]
# 0    41.81  491181  580958  1271  582228        -15.64
# 1    41.42  493300  587593   462  588055        -16.11
# 2    47.76  579934  605121  3511  608632         -4.72

# %%
df_3.shape
# Out:
# (228, 15)

# %%
merged_df_2 = pd.merge(merged_df, df_3, on=['시도', '시군구'], how='left')
merged_df_2.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  \
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
#
#    개인형이동장치(PM)/총인구수(2023년)x100000  개인형이동장치(PM)/면적(km²)  \
# 0                        4.774660             0.009608
# 1                        3.662333             0.001513
# 2                       10.155148             0.049915
#
#    개인형이동장치(PM)/인구밀도(명/km²)   자치단체      자체수입      자주재원  자치단체 예산규모  재정자주도[당초]  \
# 0                 0.049697  강원강릉시  211103.0  526699.0  1264264.0      58.36
# ...

# %%
merged_df_2.shape
# Out:
# (228, 28)

# %%
merged_df_2.columns
# Out:
# Index(['시도', '시군구', '개인형이동장치(PM)', '전체사고건수', '킥보드사고율', '총인구수(2023년)',
#        '면적(km²)', '인구밀도(명/km²)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로',
#        '개인형이동장치(PM)/총인구수(2023년)x100000', '개인형이동장치(PM)/면적(km²)',
#        '개인형이동장치(PM)/인구밀도(명/km²)', '자치단체', '자체수입', '자주재원', '자치단체 예산규모',
#        '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율', '세입', '지출', '순융자',
#        '통합재정규모', '통합재정수지비율[당초]'],
#       dtype='object')

# %%
df_4 = pd.read_csv(path_dateset + '우리 지자체 예산서(완성)v1.0(전처리)).csv').reset_index(drop=True)
df_4.head(3)
# Out:
#       시도  시군구    도로  대중교통_물류등기타    합계
# 0  서울특별시  종로구  1.79        6.19  7.98
# 1  서울특별시   중구  0.86        1.75  2.61
# 2  서울특별시  용산구  2.33        0.47  2.80

# %%
df_4.shape
# Out:
# (228, 5)

# %%
merged_df_3 = pd.merge(merged_df_2, df_4, on=['시도', '시군구'], how='left')
merged_df_3.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  \
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
#
#    개인형이동장치(PM)/총인구수(2023년)x100000  개인형이동장치(PM)/면적(km²)  \
# 0                        4.774660             0.009608
# 1                        3.662333             0.001513
# 2                       10.155148             0.049915
#
#    개인형이동장치(PM)/인구밀도(명/km²)   자치단체      자체수입      자주재원  자치단체 예산규모  재정자주도[당초]  \
# 0                 0.049697  강원강릉시  211103.0  526699.0  1264264.0      58.36
# ...

# %%
merged_df_3.shape
# Out:
# (228, 31)

# %%
merged_df_3.head(3)
# Out:
#         시도  시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)      면적(km²)  \
# 0  강원특별자치도  강릉시           10     760  1.315789     209439.0  1040.827452
# 1  강원특별자치도  고성군            1     111  0.900901      27305.0   660.766514
# 2  강원특별자치도  동해시            9     316  2.848101      88625.0   180.307717
#
#    인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  \
# 0       201.22      280.33      0.0      0.0      0.0
# 1        41.32         NaN      NaN      NaN      NaN
# 2       491.52         NaN      NaN      NaN      NaN
#
#    개인형이동장치(PM)/총인구수(2023년)x100000  개인형이동장치(PM)/면적(km²)  \
# 0                        4.774660             0.009608
# 1                        3.662333             0.001513
# 2                       10.155148             0.049915
#
#    개인형이동장치(PM)/인구밀도(명/km²)   자치단체      자체수입      자주재원  자치단체 예산규모  재정자주도[당초]  \
# 0                 0.049697  강원강릉시  211103.0  526699.0  1264264.0      58.36
# ...

# %%
def corr_single(df_O, target_var, selected_vars):
    import plotly.express as px
    import pandas as pd

    # 상관계수 계산
    corr_O = df_O[selected_vars + [target_var]].corr()[target_var].drop(target_var)

    # DataFrame 생성
    df_corr = pd.DataFrame({
        '변수': corr_O.index,
        '상관계수': corr_O.values
    })

    # Plotly 바 차트 생성
    fig = px.bar(df_corr,
                 x='변수',
                 y='상관계수',
                 title=f'Correlation with {target_var}',
                 color='상관계수',
                 color_continuous_scale='RdBu',
                 height=800,  # 높이 증가
                 width=1200)

    # 레이아웃 업데이트
    fig.update_layout(
        plot_bgcolor='white',
        title_x=0.5,
        title_font_size=20,
        xaxis_title='Variables',
        yaxis_title='Correlation Coefficient',
        yaxis_range=[-1.1, 1.1],
        showlegend=False,
        margin=dict(b=150)  # 하단 여백 증가
    )

    # x축 라벨 설정
    fig.update_xaxes(
        tickangle=90,  # 45도 각도로 회전
        tickfont=dict(size=12, family='Arial Bold'),
        tickmode='array',
        ticktext=df_corr['변수'].values,  # 원래 텍스트 사용
        showticklabels=True
    )

    # 막대 위에 수치 표시
    fig.update_traces(
        text=df_corr['상관계수'].apply(lambda x: f'{x:.3f}'),
        textposition='outside',
        textfont=dict(size=14)
    )

    # 0선 추가
    fig.add_hline(y=0, line_dash="dash", line_color="gray")

    fig.show()

# %%
def barplot_plotly(df, y_val):
  import plotly.express as px
  import pandas as pd

  # 바플롯 생성
  fig = px.bar(df, x='구분', y=y_val,
              title=f"{y_val} 사고건수",
              labels={y_val: '개인형 이동 수'},
              hover_data=[y_val],
              color=y_val,
              color_continuous_scale='Viridis')

  # 막대 위에 수치 표시
  fig.update_traces(
      text=df[y_val],
      textposition='outside',
      textfont=dict(size=12, color='black', family='Arial Bold'),  # 글씨 크기를 20으로 증가
      texttemplate='%{text:,}',
      cliponaxis=False
  )

  # x축 라벨 설정
  fig.update_xaxes(
      tickangle=90,
      tickfont=dict(size=12, family='Arial Bold')
  )

  # 그래프 레이아웃 조절
  fig.update_layout(
      width=1200,
      height=800,
      margin=dict(l=50, r=50, t=80, b=100),
      showlegend=False,
      plot_bgcolor='white',
      title_font_size=20,
      title_x=0.5,
      yaxis_range=[0, max(df[y_val]) * 1.1]  # y축 범위 조정하여 수치가 잘 보이도록
  )

  # y축 설정
  fig.update_yaxes(
      tickfont=dict(size=12),
      gridcolor='lightgray'
  )

  fig.show()

# %%
def barplot_plotly_combined(df, _title1, _titl2, y_val1, y_val2):
    import plotly.graph_objects as go

    # 첫 번째 바플롯 생성
    fig1 = go.Figure()
    fig2 = go.Figure()

    fig1.add_trace(go.Bar(
        x=df['구분'],
        y=df[y_val1],
        name=f"{y_val1}",
        text=df[y_val1],
        textposition='outside',
        marker=dict(color='blue')
    ))

    # 두 번째 바플롯 생성
    fig2.add_trace(go.Bar(
        x=df['구분'],
        y=df[y_val2],
        name=f"{y_val2}",
        text=df[y_val2],
        textposition='outside',
        marker=dict(color='orange')
    ))

    # 그래프 레이아웃 설정
    fig1.update_layout(
        title=_title1,
        barmode='group',  # 그룹형 바 그래프 설정
        width=1200,
        height=500,
        margin=dict(l=50, r=50, t=50, b=70),
        plot_bgcolor='white',
        title_font_size=20,
        title_x=0.5,
        xaxis=dict(
            tickangle=90,
            tickfont=dict(size=12, family='Arial Bold')
        ),
        yaxis=dict(
            tickfont=dict(size=12),
            gridcolor='lightgray'
        )
    )

    # 그래프 레이아웃 설정
    fig2.update_layout(
        title=_titl2,
        barmode='group',  # 그룹형 바 그래프 설정
        width=1200,
        height=500,
        margin=dict(l=50, r=50, t=50, b=50),
        plot_bgcolor='white',
        title_font_size=20,
        title_x=0.5,
        xaxis=dict(
            tickangle=90,
            tickfont=dict(size=12, family='Arial Bold')
        ),
        yaxis=dict(
            tickfont=dict(size=12),
            gridcolor='lightgray'
        )
    )

    fig1.show()
    fig2.show()

# %%
path_dateset
# Out:
# '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/최종/'

# %%
# df_PM사고_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)', ascending=False).head(50)
df_PM사고_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)/총인구수(2023년)x100000', ascending=False).head(50)
#df_PM사고_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)/총인구수(2023년)x100000', ascending=False)


# df_PM사고_top100 = merged_df_3

df_PM사고_top100['구분'] = df_PM사고_top100['시군구'] + '(' +  df_PM사고_top100['시도'] + ')'
# df_PM사고_top100['자전거보행자겸용도로'] = df_PM사고_top100['자전거보행자겸용도로'].fillna(0)
# df_PM사고_top100['자전거우선도로'] = df_PM사고_top100['자전거우선도로'].fillna(0)
# df_PM사고_top100['자전거전용도로'] = df_PM사고_top100['자전거전용도로'].fillna(0)
# df_PM사고_top100['자전거전용차로'] = df_PM사고_top100['자전거전용차로'].fillna(0)
df_PM사고_top100['자전거도로(합계)'] = df_PM사고_top100['자전거보행자겸용도로'] + df_PM사고_top100['자전거우선도로'] + df_PM사고_top100['자전거전용도로'] + df_PM사고_top100['자전거전용차로']

df_PM사고_top100['자전거보행자겸용도로/총인구수(2023년)x100000'] = df_PM사고_top100['자전거보행자겸용도로'] / df_PM사고_top100['총인구수(2023년)'] * 100000
df_PM사고_top100['자전거우선도로/총인구수(2023년)x100000'] = df_PM사고_top100['자전거우선도로'] / df_PM사고_top100['총인구수(2023년)'] * 100000
df_PM사고_top100['자전거전용도로/총인구수(2023년)x100000'] = df_PM사고_top100['자전거전용도로'] / df_PM사고_top100['총인구수(2023년)'] * 100000
df_PM사고_top100['자전거전용차로/총인구수(2023년)x100000'] = df_PM사고_top100['자전거전용차로'] / df_PM사고_top100['총인구수(2023년)'] * 100000

df_PM사고_top100['도로'] = df_PM사고_top100['도로'].fillna(0)
df_PM사고_top100['대중교통_물류등기타'] = df_PM사고_top100['대중교통_물류등기타'].fillna(0)
df_PM사고_top100['합계'] = df_PM사고_top100['합계'].fillna(0)

# cond1 = df_PM사고_top100['자전거도로(합계)'] > 0
# df_PM사고_top100 = df_PM사고_top100[cond1]
# df_PM사고_top100 = df_PM사고_top100.sort_values(by='개인형이동장치(PM)', ascending=False).head(100)
df_PM사고_top100.shape
# df_PM사고_총인구수_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)/총인구수(2023년)x100000', ascending=False).head(100)
# df_PM사고_면적_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)/면적(km²)', ascending=False).head(100)
# df_PM사고_인구밀도_top100 = merged_df_3.sort_values(by='개인형이동장치(PM)/인구밀도(명/km²)', ascending=False).head(100)
# Out:
# (50, 37)

# %%
df_PM사고_top100.columns
# Out:
# Index(['시도', '시군구', '개인형이동장치(PM)', '전체사고건수', '킥보드사고율', '총인구수(2023년)',
#        '면적(km²)', '인구밀도(명/km²)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로',
#        '개인형이동장치(PM)/총인구수(2023년)x100000', '개인형이동장치(PM)/면적(km²)',
#        '개인형이동장치(PM)/인구밀도(명/km²)', '자치단체', '자체수입', '자주재원', '자치단체 예산규모',
#        '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율', '세입', '지출', '순융자',
#        '통합재정규모', '통합재정수지비율[당초]', '도로', '대중교통_물류등기타', '합계', '구분', '자전거도로(합계)',
#        '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000',
#        '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000'],
#       dtype='object')

# %%
_columns = ['구분', '개인형이동장치(PM)', '자전거도로(합계)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로', '도로', '대중교통_물류등기타', '합계']
# df_PM사고_top100[_columns]
df_PM사고_top100['구분']
# Out:
# 102       중구(대구광역시)
# 143     영등포구(서울특별시)
# 134     동대문구(서울특별시)
# 100       서구(대구광역시)
# 141      송파구(서울특별시)
# 171       담양군(전라남도)
# 28         부천시(경기도)
# 148      중랑구(서울특별시)
# 99        북구(대구광역시)
# 130      구로구(서울특별시)
# 147       중구(서울특별시)
# 124      강남구(서울특별시)
# 18         가평군(경기도)
# 75        성주군(경상북도)
# 193    순창군(전북특별자치도)
# 224       증평군(충청북도)
# 32         안산시(경기도)
# 139      성동구(서울특별시)
# 131      금천구(서울특별시)
# 181       장성군(전라남도)
# 88        포항시(경상북도)
# 199    정읍시(전북특별자치도)
# 84        의성군(경상북도)
# 126      강북구(서울특별시)
# 118      수영구(부산광역시)
# 132      노원구(서울특별시)
# 142      양천구(서울특별시)
# 47         하남시(경기도)
# 146      종로구(서울특별시)
# 125      강동구(서울특별시)
# 144      용산구(서울특별시)
# 39         오산시(경기도)
# 54        밀양시(경상남도)
# 77        영덕군(경상북도)
# 98        동구(대구광역시)
# 66        합천군(경상남도)
# 36         양평군(경기도)
# 21         광명시(경기도)
# 74        상주시(경상북도)
# 188    군산시(전북특별자치도)
# 127      강서구(서울특별시)
# 179       영암군(전라남도)
# 104       동구(대전광역시)
# 214       청양군(충청남도)
# 72        문경시(경상북도)
# ...

# %%
df_temp = df_PM사고_top100

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# 스케일러 객체 생성
mms = MinMaxScaler()
ss = StandardScaler()
rs = RobustScaler()

#df_temp = pd.DataFrame(mms.fit_transform(df_temp[df_temp.select_dtypes(include='number').columns]), columns = df_temp.select_dtypes(include='number').columns)

# target_vars = ['개인형이동장치(PM)', '개인형이동장치(PM)/총인구수(2023년)x100000', '개인형이동장치(PM)/면적(km²)', '개인형이동장치(PM)/인구밀도(명/km²)']
target_vars = ['개인형이동장치(PM)/총인구수(2023년)x100000']

for tv in target_vars:
  target_var = tv
  # selected_vars = ['총인구수(2023년)', '면적(km²)', '인구밀도(명/km²)',\
  #                  '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로', '자전거도로(합계)',\
  #                  '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
  #                  '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
  #                  '도로', '대중교통_물류등기타', '합계']
  selected_vars = ['총인구수(2023년)', '면적(km²)', '인구밀도(명/km²)',\
                  '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
                  '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
                  '도로', '대중교통_물류등기타', '합계']
  corr_single(df_temp, target_var, selected_vars)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-ce24a5c7267f> in <cell line: 17>()
#      26                   '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
#      27                   '도로', '대중교통_물류등기타', '합계']
# ---> 28   corr_single(df_temp, target_var, selected_vars)
#
# <ipython-input-34-01c65ac5436a> in corr_single(df_O, target_var, selected_vars)
#       4
#       5     # 상관계수 계산
# ----> 6     corr_O = df_O[selected_vars + [target_var]].corr()[target_var].drop(target_var)
#       7
#       8     # DataFrame 생성
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# ...

# %%
df_temp.head(2)
# Out:
#         시도   시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)    면적(km²)  \
# 102  대구광역시    중구           41     772  5.310881      89064.0   7.055595
# 143  서울특별시  영등포구          150    1901  7.890584     374794.0  24.551194
#
#      인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  개인형이동장치(PM)/10만명당인구  \
# 102     12623.17         NaN      NaN      NaN      NaN            46.034312
# 143     15265.82         NaN      NaN      NaN      NaN            40.021985
#
#      개인형이동장치(PM)/면적(km²)  개인형이동장치(PM)/인구밀도(명/km²)    자치단체      자체수입      자주재원  \
# 102             5.810991                 0.003248    대구중구   82309.0   53643.0
# 143             6.109682                 0.009826  서울영등포구  306015.0  102681.0
#
#      자치단체 예산규모  재정자주도[당초]  재정자립도[당초]  교부세비율  국고보조금비율        세입        지출  \
# 102   325000.0      41.83      25.33   16.5    58.17  305304.0  324146.0
# 143   870047.0      46.97      35.17   11.8    53.03  823745.0  881354.0
#
# ...

# %%
target_var = '개인형이동장치(PM)/10만명당인구'
selected_vars = ['총인구수(2023년)', '면적(km²)', '인구밀도(명/km²)',\
                  '자전거보행자겸용도로/10만명당인구', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
                  '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
                  '도로', '대중교통_물류등기타', '합계']

# 상관계수 계산
corr_O = df_temp[selected_vars + [target_var]].corr()[target_var].drop(target_var)

# DataFrame 생성
correlation_matrix = pd.DataFrame({
    '변수': corr_O.index,
    '상관계수': corr_O.values
})

#correlation_matrix
correlation_matrix[correlation_matrix['변수'].isin(['인구밀도(명/km²)', '자전거보행자겸용도로/10만명당인구', '도로'])]
# Out:
#                     변수      상관계수
# 2          인구밀도(명/km²)  0.347575
# 3   자전거보행자겸용도로/10만명당인구 -0.510995
# 11                  도로 -0.194453

# %%
correlation_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   변수      14 non-null     object
#  1   상관계수    14 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 352.0+ bytes

# %%
def find_highly_correlated_rows(df, correlation_matrix):
    correlated_features = []
    for column in correlation_matrix.columns:
        # high_corr_columns = correlation_matrix.index[(correlation_matrix[column].abs() > threshold) & (correlation_matrix[column] < 1)].tolist()
        high_corr_columns = correlation_matrix.index[(correlation_matrix[column] < 1.0)].tolist()
        if high_corr_columns:
            correlated_features.extend(high_corr_columns)

    correlated_features = list(set(correlated_features))

    if correlated_features:
        return df[correlated_features]
    else:
        return "상관계수 임계값을 만족하는 행이 없습니다."

# %%
filtered_rows = find_highly_correlated_rows(df_temp, correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-10f00422c28e> in <cell line: 1>()
# ----> 1 filtered_rows = find_highly_correlated_rows(df_temp, correlation_matrix)
#
# <ipython-input-89-99ea241cb6f2> in find_highly_correlated_rows(df, correlation_matrix)
#       3     for column in correlation_matrix.columns:
#       4         # high_corr_columns = correlation_matrix.index[(correlation_matrix[column].abs() > threshold) & (correlation_matrix[column] < 1)].tolist()
# ----> 5         high_corr_columns = correlation_matrix.index[(correlation_matrix[column] < 1.0)].tolist()
#       6         if high_corr_columns:
#       7             correlated_features.extend(high_corr_columns)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ...

# %%
df_PM사고_top100.rename(columns = {'개인형이동장치(PM)/총인구수(2023년)x100000' : '개인형이동장치(PM)/10만명당인구'}, inplace = True)
df_PM사고_top100.rename(columns = {'자전거보행자겸용도로/총인구수(2023년)x100000' : '자전거보행자겸용도로/10만명당인구'}, inplace = True)

df_PM사고_top100.columns
# Out:
# Index(['시도', '시군구', '개인형이동장치(PM)', '전체사고건수', '킥보드사고율', '총인구수(2023년)',
#        '면적(km²)', '인구밀도(명/km²)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로',
#        '개인형이동장치(PM)/10만명당인구', '개인형이동장치(PM)/면적(km²)', '개인형이동장치(PM)/인구밀도(명/km²)',
#        '자치단체', '자체수입', '자주재원', '자치단체 예산규모', '재정자주도[당초]', '재정자립도[당초]', '교부세비율',
#        '국고보조금비율', '세입', '지출', '순융자', '통합재정규모', '통합재정수지비율[당초]', '도로',
#        '대중교통_물류등기타', '합계', '구분', '자전거도로(합계)', '자전거보행자겸용도로/10만명당인구',
#        '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000',
#        '자전거전용차로/총인구수(2023년)x100000'],
#       dtype='object')

# %%
# barplot_plotly(df_PM사고_top100, '개인형이동장치(PM)')
# barplot_plotly(df_PM사고_top100, '자전거도로(합계)')

# 20241105 duzin
# barplot_plotly(df_PM사고_top100, '개인형이동장치(PM)/총인구수(2023년)x100000')
# barplot_plotly(df_PM사고_top100, '자전거보행자겸용도로/총인구수(2023년)x100000')
barplot_plotly(df_PM사고_top100, '개인형이동장치(PM)/10만명당인구')
barplot_plotly(df_PM사고_top100, '자전거보행자겸용도로/10만명당인구')

barplot_plotly(df_PM사고_top100, '인구밀도(명/km²)')
barplot_plotly(df_PM사고_top100, '도로')
barplot_plotly(df_PM사고_top100, '국고보조금비율')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_PM사고_top100.columns
# Out:
# Index(['시도', '시군구', '개인형이동장치(PM)', '전체사고건수', '킥보드사고율', '총인구수(2023년)',
#        '면적(km²)', '인구밀도(명/km²)', '자전거보행자겸용도로', '자전거우선도로', '자전거전용도로', '자전거전용차로',
#        '개인형이동장치(PM)/10만명당인구', '개인형이동장치(PM)/면적(km²)', '개인형이동장치(PM)/인구밀도(명/km²)',
#        '자치단체', '자체수입', '자주재원', '자치단체 예산규모', '재정자주도[당초]', '재정자립도[당초]', '교부세비율',
#        '국고보조금비율', '세입', '지출', '순융자', '통합재정규모', '통합재정수지비율[당초]', '도로',
#        '대중교통_물류등기타', '합계', '구분', '자전거도로(합계)', '자전거보행자겸용도로/10만명당인구',
#        '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000',
#        '자전거전용차로/총인구수(2023년)x100000'],
#       dtype='object')

# %%
# barplot_plotly(df_PM사고_top100, '개인형이동장치(PM)/10만명당인구')
# barplot_plotly(df_PM사고_top100, '자전거보행자겸용도로/10만명당인구')

# barplot_plotly(df_PM사고_top100, '인구밀도(명/km²)')
# barplot_plotly(df_PM사고_top100, '도로')
# barplot_plotly(df_PM사고_top100, '국고보조금비율')

#barplot_plotly_combined(df_PM사고_top100, '개인형이동장치(PM) 와 자전거보행자겸용도로 비교', '개인형이동장치(PM)/10만명당인구', '자전거보행자겸용도로/10만명당인구')


# barplot_plotly_combined(df_PM사고_top100, '개인형이동장치(PM)/10만명당인구', '인구밀도(명/km²)')
#barplot_plotly_combined(df_PM사고_top100, '개인형이동장치(PM)/10만명당인구', '도로')
#barplot_plotly_combined(df_PM사고_top100, '개인형이동장치(PM)/10만명당인구', '국고보조금비율')

# %% [markdown]
# ---
# ## 회귀 분석

# %%
df_PM사고_top100.head(3)
# Out:
#         시도   시군구  개인형이동장치(PM)  전체사고건수    킥보드사고율  총인구수(2023년)    면적(km²)  \
# 102  대구광역시    중구           41     772  5.310881      89064.0   7.055595
# 143  서울특별시  영등포구          150    1901  7.890584     374794.0  24.551194
# 134  서울특별시  동대문구          119    1676  7.100239     341149.0  14.215912
#
#      인구밀도(명/km²)  자전거보행자겸용도로  자전거우선도로  자전거전용도로  자전거전용차로  개인형이동장치(PM)/10만명당인구  \
# 102     12623.17         NaN      NaN      NaN      NaN            46.034312
# 143     15265.82         NaN      NaN      NaN      NaN            40.021985
# 134     23997.69         NaN      NaN      NaN      NaN            34.882119
#
#      개인형이동장치(PM)/면적(km²)  개인형이동장치(PM)/인구밀도(명/km²)    자치단체      자체수입      자주재원  \
# 102             5.810991                 0.003248    대구중구   82309.0   53643.0
# 143             6.109682                 0.009826  서울영등포구  306015.0  102681.0
# 134             8.370901                 0.004959  서울동대문구  169458.0  190990.0
#
# ...

# %%
_columns_X = ['총인구수(2023년)', '면적(km²)', '인구밀도(명/km²)',\
                  '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
                  '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
                  '도로', '대중교통_물류등기타', '합계']

X = df_PM사고_top100[_columns_X]
y = df_PM사고_top100['개인형이동장치(PM)/총인구수(2023년)x100000']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c96a5b712031> in <cell line: 6>()
#       4                   '도로', '대중교통_물류등기타', '합계']
#       5
# ----> 6 X = df_PM사고_top100[_columns_X]
#       7 y = df_PM사고_top100['개인형이동장치(PM)/총인구수(2023년)x100000']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
print(X.isnull().sum().sum(), y.isnull().sum().sum())

# %%
print(X.shape, y.shape)

# %%
X.head(3)

# %%
y.head(3)

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# _columns_X = ['총인구수(2023년)', '면적(km²)', '인구밀도(명/km²)',\
#                   '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
#                   '재정자주도[당초]', '재정자립도[당초]', '교부세비율', '국고보조금비율',\
#                   '도로', '대중교통_물류등기타', '합계']
_columns_X = ['총인구수(2023년)',\
              '자전거보행자겸용도로/총인구수(2023년)x100000', '자전거우선도로/총인구수(2023년)x100000', '자전거전용도로/총인구수(2023년)x100000', '자전거전용차로/총인구수(2023년)x100000',\
              '재정자립도[당초]', '교부세비율', '국고보조금비율',\
              '도로']

X = df_PM사고_top100[_columns_X]
y = df_PM사고_top100['개인형이동장치(PM)/총인구수(2023년)x100000']

X.fillna(0, inplace = True)
y.fillna(0, inplace = True)

# 특성(X) 스케일링
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
#X_scaled = pd.DataFrame(X_scaled, columns = _columns_X)

#X_scaled = X

X_scaled = sm.add_constant(X_scaled)#, has_constant = "add")
# sm OLS 적합
model1 = sm.OLS(y, X_scaled)
fitted_model1 = model1.fit()

print(X.columns)
# summary 함수통해 결과출력
fitted_model1.summary()

# %%
X.isnull().sum()
