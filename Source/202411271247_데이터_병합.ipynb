# %% [markdown]
# ## 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## 필요 라이브러리 임포트
# - 추가 사용자 정의함수 불러오기

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

import time

import folium

# 사용자 정의함수 경로 설정
import sys
# sys.path.append("H:/내 드라이브/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")
sys.path.append("/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

import dataset_function as ds_f
import folium_function as fl_f
import plot_function as pl_f

# %% [markdown]
# ### 데이터셋 기본 경로 설정

# %%
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/'

# %% [markdown]
# ### 서브 폴더 경로

# %%
path_sub = '원본/'
print(f'path : {path_dateset + path_sub}')
# Out:
# path : /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/
# path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/재정수입구조(본예산총수입기준)_20241126155035.csv , encoding :  UTF-8-SIG
# ==============================================================
# .csv, 재정수입구조(본예산총수입기준)_20241126155035.csv, 9
# ['No.', '회계연도', '예산기금구분명', '회계구분명', '세목분류명', '총수입(조원)']
# [2, 2023, '예산', '일반회계', '세외수입', 9.7]

# %% [markdown]
# ### 서브폴더의 전체 파일 확인 (컬럼명 확인)

# %%
em.Check_File(path_dateset, path_sub)

# %%
em.Columns_Check(path_dateset, path_sub)

# %% [markdown]
# ### 서브폴더의 전체 파일 병합

# %%
em.Merge_File(path_dateset, path_sub)
# Out:
# path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/재정수입구조(본예산총수입기준)_20241126155035.csv , encoding :  UTF-8-SIG
# ==============================================================
# .csv, 재정수입구조(본예산총수입기준)_20241126155035.csv, 9
# ['No.', '회계연도', '예산기금구분명', '회계구분명', '세목분류명', '총수입(조원)']
# ==============================================================
# Save Complete : /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/merge.parquet

# %% [markdown]
# ### 병합된 파일 확인

# %%
file_name = '원본/merge.parquet'
df_temp = em.Read_File(path_dateset + file_name)

# %%
df_temp.head()
# Out:
#    No.  회계연도 예산기금구분명   회계구분명 세목분류명  총수입(조원)
# 0    1  2023      예산    일반회계  국세수입    390.3
# 1    2  2023      예산    일반회계  세외수입      9.7
# 2    3  2023      예산  기타특별회계  국세수입     10.2
# 3    4  2023      예산  기타특별회계  세외수입      8.2
# 4    5  2023      예산  기업특별회계  세외수입      6.3
