# %% [markdown]
# ## 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## 필요 라이브러리 임포트
# - 추가 사용자 정의함수 불러오기

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

import time

import folium

# 사용자 정의함수 경로 설정
import sys
# sys.path.append("H:/내 드라이브/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")
sys.path.append("/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

import dataset_function as ds_f
import folium_function as fl_f
import plot_function as pl_f

# %% [markdown]
# ### 데이터셋 기본 경로 설정

# %%
# 나의 루트 경로 설정
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/'

# %% [markdown]
# ### 파일 이름 설정

# %%
file_name = '원본/열린재정_재정연구분석_재정분석통계_상세재정통계/결산_세입세출_세출지출 결산 현황_2023년.csv'

# %% [markdown]
# ### 데이터의 행 개수만큼만 읽기
# - 대용량 파일의 경우, 파일의 형식을 먼저 확인하기 위해서 사용

# %%
er.Read_nrows(path_dateset + file_name, 3)
# Out:
#    No.  회계연도             소관명   회계명  계정명  분야      분야명  부문   부문명  프로그램  ...  \
# 0    1  2023  대통령비서실 및 국가안보실  일반회계  NaN  10  일반·지방행정  16  일반행정  1000  ...
# 1    2  2023  대통령비서실 및 국가안보실  일반회계  NaN  10  일반·지방행정  16  일반행정  1000  ...
# 2    3  2023  대통령비서실 및 국가안보실  일반회계  NaN  10  일반·지방행정  16  일반행정  1000  ...
#
#         전용감액(원)  이용증액(원) 이용감액(원)  이체증액(원) 이체감액(원) 세출예산현액/지출계획현액(원)  \
# 0  -140,000,000        0       0        0       0   42,288,000,000
# 1             0        0       0        0       0    3,519,787,000
# 2  -230,000,000        0       0        0       0    9,991,126,000
#
#            지출액(원)         지출순액(원)  다음년도이월액(원)         불용액(원)
# 0  36,623,494,680  36,623,494,680           0  5,664,505,320
# 1   3,020,814,940   3,020,814,940           0    498,972,060
# 2   9,617,415,320   9,617,415,320           0    373,710,680
#
# [3 rows x 32 columns]

# %% [markdown]
# ### 파일읽기

# %%
df_temp = em.Read_File(path_dateset + file_name)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/열린재정_재정연구분석_재정분석통계_상세재정통계/결산_세입세출_세출지출 결산 현황_2023년.csv , encoding :  UTF-8-SIG

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12055 entries, 0 to 12054
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               12055 non-null  int64
#  1   회계연도              12055 non-null  int64
#  2   소관명               12055 non-null  object
#  3   회계명               12055 non-null  object
#  4   계정명               2130 non-null   object
#  5   분야                12055 non-null  int64
#  6   분야명               12055 non-null  object
#  7   부문                12055 non-null  object
#  8   부문명               12055 non-null  object
#  9   프로그램              12055 non-null  int64
#  10  프로그램명             12055 non-null  object
#  11  단위사업              12055 non-null  int64
#  12  단위사업명             12055 non-null  object
#  13  지출목               12055 non-null  int64
#  14  지출목명              12055 non-null  object
#  15  세출예산액/당초지출계획액(원)  12055 non-null  object
#  16  세출예산액/수정지출계획액(원)  12055 non-null  object
#  17  전년도이월액(원)         12055 non-null  object
#  18  초과지출승인액(원)        12055 non-null  object
#  19  예비비지출결정증액(원)      12055 non-null  object
#  20  예비비지출결정감액(원)      12055 non-null  object
#  21  전용증액(원)           12055 non-null  object
#  22  전용감액(원)           12055 non-null  object
#  23  이용증액(원)           12055 non-null  object
#  24  이용감액(원)           12055 non-null  object
#  25  이체증액(원)           12055 non-null  object
#  26  이체감액(원)           12055 non-null  object
#  27  세출예산현액/지출계획현액(원)  12055 non-null  object
#  28  지출액(원)            12055 non-null  object
#  29  지출순액(원)           12055 non-null  object
#  30  다음년도이월액(원)        12055 non-null  object
#  31  불용액(원)            12055 non-null  object
# dtypes: int64(6), object(26)
# memory usage: 2.9+ MB

# %%
df_temp.columns
# Out:
# Index(['No.', '회계연도', '소관명', '회계명', '계정명', '분야', '분야명', '부문', '부문명', '프로그램',
#        '프로그램명', '단위사업', '단위사업명', '지출목', '지출목명', '세출예산액/당초지출계획액(원)',
#        '세출예산액/수정지출계획액(원)', '전년도이월액(원)', '초과지출승인액(원)', '예비비지출결정증액(원)',
#        '예비비지출결정감액(원)', '전용증액(원)', '전용감액(원)', '이용증액(원)', '이용감액(원)', '이체증액(원)',
#        '이체감액(원)', '세출예산현액/지출계획현액(원)', '지출액(원)', '지출순액(원)', '다음년도이월액(원)',
#        '불용액(원)'],
#       dtype='object')

# %%
# 소관명', '회계명', '계정명', '수입관', '수입관명', '수입항', '수입항명
df_temp.value_counts(['지출목명'])
# Out:
# 지출목명
# 운영비           1630
# 민간이전          1434
# 여비            1306
# 업무추진비         1241
# 연구용역비         1088
# 인건비            934
# 유형자산           924
# 자치단체이전         592
# 보전금            519
# 건설비            509
# 일반출연금          347
# 직무수행경비         319
# 연구개발출연금        310
# 해외이전           152
# 전출금등           150
# 무형자산           116
# 건설보상비           94
# 예치금및유가증권매입      94
# 융자금             75
# 상환지출            67
# 출자금             47
# 예비비및기타          43
# 특수활동비           32
# 예탁금             27
# 지분취득비            3
# 안보비              1
# 정보보안비            1
# Name: count, dtype: int64

# %%
ee.ss_isnull(df_temp)
# Out:
#                [컬럼명]  [sum]  [sum_isnull]  [mean_isnull(%)]
# 0                No.   1634             0          0.000000
# 1               회계연도   1634             0          0.000000
# 2                소관명   1634             0          0.000000
# 3                회계명   1634             0          0.000000
# 4                계정명    656           978         59.853121
# 5                수입관   1634             0          0.000000
# 6               수입관명   1634             0          0.000000
# 7                수입항   1634             0          0.000000
# 8               수입항명   1634             0          0.000000
# 9   세입예산액/당초수입계획액(원)   1634             0          0.000000
# 10  세입예산액/수정수입계획액(원)   1634             0          0.000000
# 11         이체등증감액(원)   1634             0          0.000000
# 12  세입예산현액/수입계획현액(원)   1634             0          0.000000
# 13          징수결정액(원)   1634             0          0.000000
# 14            수납액(원)   1634             0          0.000000
# 15           수납순액(원)   1634             0          0.000000
# 16          불납결손액(원)   1634             0          0.000000
# 17           미수납액(원)   1634             0          0.000000
