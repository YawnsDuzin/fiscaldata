# %%
import matplotlib.pyplot as plt

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows의 경우
plt.rcParams['axes.unicode_minus'] = False  # 한글 폰트 사용 시, 마이너스 기호 깨짐 방지
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,194 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123630 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ## 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## 필요 라이브러리 임포트
# - 추가 사용자 정의함수 불러오기

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

import time

import folium

# 사용자 정의함수 경로 설정
import sys
# sys.path.append("H:/내 드라이브/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")
sys.path.append("/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

import dataset_function as ds_f
import folium_function as fl_f
import plot_function as pl_f

# %% [markdown]
# ### 데이터셋 기본 경로 설정

# %%
# 나의 루트 경로 설정
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/'

# %% [markdown]
# ### 파일 이름 설정

# %%
file_name_1 = '전처리/가해운전자_차량용도별_교차로형태별_교통사고_2020_2023.csv'
file_name_2 = '전처리/가해운전자_차량용도별_도로종류별_교통사고_2020_2023.csv'
file_name_3 = '전처리/가해운전자_차량용도별_도로형태별_교통사고_2020_2023.csv'
file_name_4 = '전처리/가해운전자_차량용도별_연령층별_교통사고_2020_2023.csv'

# %%
file_name = file_name_4
x_label = '연령층'

# %% [markdown]
# ### 데이터의 행 개수만큼만 읽기
# - 대용량 파일의 경우, 파일의 형식을 먼저 확인하기 위해서 사용

# %%
er.Read_nrows(path_dateset + file_name, 3)
# Out:
#      연도     구분  20세이하  21~30세  31~40세  41~50세  51~60세  61~64세  65세이상  연령불명
# 0  2020  사고[건]    209     314     163      99      59      17     30     6
# 1  2020  사망[명]      1       2       0       1       4       0      2     0
# 2  2020  부상[명]    244     338     176     109      59      19     34     6

# %% [markdown]
# ### 파일읽기

# %%
df_temp = em.Read_File(path_dateset + file_name)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/전처리/가해운전자_차량용도별_연령층별_교통사고_2020_2023.csv , encoding :  UTF-8-SIG

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      12 non-null     int64
#  1   구분      12 non-null     object
#  2   20세이하   12 non-null     int64
#  3   21~30세  12 non-null     int64
#  4   31~40세  12 non-null     int64
#  5   41~50세  12 non-null     int64
#  6   51~60세  12 non-null     int64
#  7   61~64세  12 non-null     int64
#  8   65세이상   12 non-null     int64
#  9   연령불명    12 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 1.1+ KB

# %%
df_temp.columns
# Out:
# Index(['연도', '구분', '20세이하', '21~30세', '31~40세', '41~50세', '51~60세', '61~64세',
#        '65세이상', '연령불명'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_temp
# Out:
#       연도     구분  20세이하  21~30세  31~40세  41~50세  51~60세  61~64세  65세이상  연령불명
# 0   2020  사고[건]    209     314     163      99      59      17     30     6
# 1   2020  사망[명]      1       2       0       1       4       0      2     0
# 2   2020  부상[명]    244     338     176     109      59      19     34     6
# 3   2021  사고[건]    628     555     218     138      89      19     62    26
# 4   2021  사망[명]      3       2       4       3       3       3      1     0
# 5   2021  부상[명]    710     604     239     146      94      16     66    26
# 6   2022  사고[건]   1096     648     254     169     102      22     64    31
# 7   2022  사망[명]      5       6       2       4       5       1      3     0
# 8   2022  부상[명]   1247     742     276     186     111      22     69    31
# 9   2023  사고[건]   1077     576     250     187     156      32     89    22
# 10  2023  사망[명]      3       3       6       4       5       0      3     0
# 11  2023  부상[명]   1207     628     264     195     172      35     99    22

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# 데이터 준비 (df_temp가 이미 존재한다고 가정)
gb = ['사고[건]', '사망[명]', '부상[명]']

# 색상 팔레트 생성
# color_palette = px.colors.sequential.Aggrnyl
# color_palette = px.colors.sequential.Blues[::-1]
color_palette = px.colors.cyclical.HSV[::-1]

# 서브플롯 생성
fig = make_subplots(rows=len(gb), cols=1, subplot_titles=[f'{x_label}별 사고 현황 ({g})' for g in gb])

for i, g in enumerate(gb, start=1):
    df = df_temp[df_temp['구분'] == g].drop(columns = ['구분']) #[['연도', '교차로아님', '교차로 - 삼지', '교차로 - 사지', '교차로 - 오지이상', '교차로 - 회전']]
    df_melted = df.melt(id_vars=['연도'], var_name=x_label, value_name='사고수')
    df_melted['사고수'] = df_melted['사고수'].fillna(0)
    df_melted['사고수'] = df_melted['사고수'].astype(int)

    for j, year in enumerate(df_melted['연도'].unique()):
        subset = df_melted[df_melted['연도'] == year]
        color = color_palette[j % len(color_palette)]  # 색상 순환
        fig.add_trace(
            go.Scatter(
                x=subset[x_label],
                y=subset['사고수'],
                mode='lines+markers',
                name=str(year),
                line=dict(color=color),
                marker=dict(color=color),
                showlegend=(i==1)
            ),
            row=i, col=1
        )

    fig.update_xaxes(title_text=x_label, row=i, col=1)
    fig.update_yaxes(title_text='사고 수', row=i, col=1)

# 전체 레이아웃 업데이트
fig.update_layout(
    height=300*len(gb),
    title_text=x_label + '별 사고 현황',
    legend_title_text='연도',
    font=dict(family='NanumGothic'),
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

# X축과 Y축 눈금 글씨 크기 조정
fig.update_xaxes(
    tickfont=dict(size=12, family='Arial', color='gray'),
    tickmode='array',
    tickvals=df_melted[x_label].unique(),
    ticktext=df_melted[x_label].unique(),
    tickangle=15
)
fig.update_yaxes(tickfont=dict(size=12, family='Arial', color='gray'))

# 그래프 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b323f575-9b06-4893-b531-c1ec8e16af78" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b323f575-9b06-4893-b531-c1ec8e16af78")) {                    Plotly.newPlot(                        "b323f575-9b06-4893-b531-c1ec8e16af78",                        [{"line":{"color":"#ff0000"},"marker":{"color":"#ff0000"},"mode":"lines+markers","name":"2020","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[209,314,163,99,59,17,30,6],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#ff00bf"},"marker":{"color":"#ff00bf"},"mode":"lines+markers","name":"2021","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[628,555,218,138,89,19,62,26],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#9700ff"},"marker":{"color":"#9700ff"},"mode":"lines+markers","name":"2022","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1096,648,254,169,102,22,64,31],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#0010ff"},"marker":{"color":"#0010ff"},"mode":"lines+markers","name":"2023","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1077,576,250,187,156,32,89,22],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#ff0000"},"marker":{"color":"#ff0000"},"mode":"lines+markers","name":"2020","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1,2,0,1,4,0,2,0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#ff00bf"},"marker":{"color":"#ff00bf"},"mode":"lines+markers","name":"2021","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[3,2,4,3,3,3,1,0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#9700ff"},"marker":{"color":"#9700ff"},"mode":"lines+markers","name":"2022","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[5,6,2,4,5,1,3,0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#0010ff"},"marker":{"color":"#0010ff"},"mode":"lines+markers","name":"2023","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[3,3,6,4,5,0,3,0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#ff0000"},"marker":{"color":"#ff0000"},"mode":"lines+markers","name":"2020","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[244,338,176,109,59,19,34,6],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#ff00bf"},"marker":{"color":"#ff00bf"},"mode":"lines+markers","name":"2021","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[710,604,239,146,94,16,66,26],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#9700ff"},"marker":{"color":"#9700ff"},"mode":"lines+markers","name":"2022","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1247,742,276,186,111,22,69,31],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#0010ff"},"marker":{"color":"#0010ff"},"mode":"lines+markers","name":"2023","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1207,628,264,195,172,35,99,22],"type":"scatter","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556 ...

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# 데이터 준비 (df_temp가 이미 존재한다고 가정)
gb = ['사고[건]', '사망[명]', '부상[명]']

# 색상 팔레트 생성
# color_palette = px.colors.sequential.Aggrnyl
color_palette = px.colors.cyclical.HSV[::-1]

# 서브플롯 생성
fig = make_subplots(rows=len(gb), cols=1, subplot_titles=[f'{x_label}별 사고 현황 ({g})' for g in gb])

for i, g in enumerate(gb, start=1):
    df = df_temp[df_temp['구분'] == g].drop(columns = ['구분']) #[['연도', '교차로아님', '교차로 - 삼지', '교차로 - 사지', '교차로 - 오지이상', '교차로 - 회전']]
    df_melted = df.melt(id_vars=['연도'], var_name=x_label, value_name='사고수')
    df_melted['사고수'] = df_melted['사고수'].fillna(0)
    df_melted['사고수'] = df_melted['사고수'].astype(int)

    for j, year in enumerate(sorted(df_melted['연도'].unique(), reverse=True)):
        subset = df_melted[df_melted['연도'] == year]
        color = color_palette[j % len(color_palette)]  # 색상 순환
        fig.add_trace(
            go.Bar(
                x=subset[x_label],
                y=subset['사고수'],
                name=str(year),
                marker_color=color,
                showlegend=(i==1)
            ),
            row=i, col=1
        )

    fig.update_xaxes(title_text=x_label, row=i, col=1)
    fig.update_yaxes(title_text='사고 수', row=i, col=1)

# 전체 레이아웃 업데이트
fig.update_layout(
    height=300*len(gb),
    title_text=x_label + '별 사고 현황',
    legend_title_text='연도',
    font=dict(family='NanumGothic'),
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    ),
    barmode='stack'
)

# X축과 Y축 눈금 글씨 크기 조정
fig.update_xaxes(tickfont=dict(size=12, family='Arial', color='gray'))
fig.update_yaxes(tickfont=dict(size=12, family='Arial', color='gray'))

# 그래프 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="818c8ecc-818b-45d2-aec4-a0e27f6dded2" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("818c8ecc-818b-45d2-aec4-a0e27f6dded2")) {                    Plotly.newPlot(                        "818c8ecc-818b-45d2-aec4-a0e27f6dded2",                        [{"marker":{"color":"#ff0000"},"name":"2023","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1077,576,250,187,156,32,89,22],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#ff00bf"},"name":"2022","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1096,648,254,169,102,22,64,31],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#9700ff"},"name":"2021","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[628,555,218,138,89,19,62,26],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0010ff"},"name":"2020","showlegend":true,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[209,314,163,99,59,17,30,6],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#ff0000"},"name":"2023","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[3,3,6,4,5,0,3,0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#ff00bf"},"name":"2022","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[5,6,2,4,5,1,3,0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#9700ff"},"name":"2021","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[3,2,4,3,3,3,1,0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#0010ff"},"name":"2020","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1,2,0,1,4,0,2,0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#ff0000"},"name":"2023","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1207,628,264,195,172,35,99,22],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#ff00bf"},"name":"2022","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[1247,742,276,186,111,22,69,31],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#9700ff"},"name":"2021","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[710,604,239,146,94,16,66,26],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#0010ff"},"name":"2020","showlegend":false,"x":["20세이하","21~30세","31~40세","41~50세","51~60세","61~64세","65세이상","연령불명"],"y":[244,338,176,109,59,19,34,6],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""}," ...
