# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,643 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# ## 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## 필요 라이브러리 임포트
# - 추가 사용자 정의함수 불러오기

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

import time

import folium

# 사용자 정의함수 경로 설정
import sys
# sys.path.append("H:/내 드라이브/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")
sys.path.append("/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

import dataset_function as ds_f
import folium_function as fl_f
import plot_function as pl_f

# %%
# 나의 루트 경로 설정
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/'

# %%
file_name_1 = '원본/재정자립도당초자치단체2024122220313.csv'
file_name_2 = '원본/재정자주도당초자치단체2024122212422.csv'
file_name_3 = '원본/통합재정수지비율당초자치단체2024122212458.csv'

savefile_name_1 = '원본/재정자립도당초자치단체(전처리)).csv'
savefile_name_2 = '원본/재정자주도당초자치단체(전처리)).csv'
savefile_name_3 = '원본/통합재정수지비율당초자치단체(전처리)).csv'

# %% [markdown]
# ## 전처리 할 파일 선택

# %%
file_name = file_name_3
savefile_name = savefile_name_3

# %%
df_temp = em.Read_File(path_dateset + file_name)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/통합재정수지비율당초자치단체2024122212458.csv , encoding :  UTF-8-SIG

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   지자체명          244 non-null    object
#  1   세입            244 non-null    object
#  2   지출            244 non-null    object
#  3   순융자           244 non-null    object
#  4   통합재정규모        244 non-null    object
#  5   통합재정수지비율[당초]  244 non-null    object
# dtypes: object(6)
# memory usage: 11.6+ KB

# %%
if savefile_name == savefile_name_3:
  print('Column Rename Success!!')
  df_temp.rename(columns = {'지자체명' : '자치단체'}, inplace = True)
# Out:
# Column Rename Success!!

# %%
df_temp
# Out:
#       자치단체          세입          지출      순융자      통합재정규모       통합재정수지비율[당초]
# 0     지자체명         (A)         (B)      (C)         (D)  ((A-(B+C))/D)x100
# 1     서울본청  36,297,587  37,145,389  499,921  37,645,310              -3.58
# 2    서울종로구     491,181     580,958    1,271     582,228             -15.64
# 3     서울중구     493,300     587,593      462     588,055             -16.11
# 4    서울용산구     579,934     605,121    3,511     608,632              -4.72
# ..     ...         ...         ...      ...         ...                ...
# 239  경남산청군     539,844     608,361    1,465     609,826             -11.48
# 240  경남함양군     528,788     588,379    4,752     593,131             -10.85
# 241  경남거창군     657,970     730,724    2,876     733,600             -10.31
# 242  경남합천군     723,434     729,945    1,420     731,365              -1.08
# 243   제주본청   6,269,014   6,619,951   18,709   6,638,659              -5.57
#
# [244 rows x 6 columns]

# %%
df_temp_2 = df_temp.iloc[1:]
df_temp_2
# Out:
#       자치단체          세입          지출      순융자      통합재정규모 통합재정수지비율[당초]
# 1     서울본청  36,297,587  37,145,389  499,921  37,645,310        -3.58
# 2    서울종로구     491,181     580,958    1,271     582,228       -15.64
# 3     서울중구     493,300     587,593      462     588,055       -16.11
# 4    서울용산구     579,934     605,121    3,511     608,632        -4.72
# 5    서울성동구     656,342     726,047      702     726,749        -9.69
# ..     ...         ...         ...      ...         ...          ...
# 239  경남산청군     539,844     608,361    1,465     609,826       -11.48
# 240  경남함양군     528,788     588,379    4,752     593,131       -10.85
# 241  경남거창군     657,970     730,724    2,876     733,600       -10.31
# 242  경남합천군     723,434     729,945    1,420     731,365        -1.08
# 243   제주본청   6,269,014   6,619,951   18,709   6,638,659        -5.57
#
# [243 rows x 6 columns]

# %%
df_temp_2.shape
# Out:
# (243, 6)

# %%
cond1 = df_temp_2['자치단체'].str.contains('본청')
cond2 = df_temp_2['자치단체'].isin(['세종본청', '제주본청'])

df_temp_3 = df_temp_2[~(cond1 & ~cond2)]

# %%
print(df_temp_2.shape, df_temp_3.shape)
# Out:
# (243, 6) (228, 6)

# %%
df_temp_3[cond1]
# Out:
# <ipython-input-150-576fe8bc33f7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_temp_3[cond1]
#      자치단체         세입         지출     순융자     통합재정규모 통합재정수지비율[당초]
# 83   세종본청  1,611,838  1,683,823  21,229  1,705,052        -5.47
# 243  제주본청  6,269,014  6,619,951  18,709  6,638,659        -5.57

# %%
df_temp_3['자치단체'] = df_temp_2['자치단체'].str.replace('본청', '')
# Out:
# <ipython-input-151-ba68dd6f3e76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['자치단체'] = df_temp_2['자치단체'].str.replace('본청', '')

# %%
df_temp_3
# Out:
#       자치단체         세입         지출     순융자     통합재정규모 통합재정수지비율[당초]
# 2    서울종로구    491,181    580,958   1,271    582,228       -15.64
# 3     서울중구    493,300    587,593     462    588,055       -16.11
# 4    서울용산구    579,934    605,121   3,511    608,632        -4.72
# 5    서울성동구    656,342    726,047     702    726,749        -9.69
# 6    서울광진구    699,821    838,720   1,795    840,515       -16.74
# ..     ...        ...        ...     ...        ...          ...
# 239  경남산청군    539,844    608,361   1,465    609,826       -11.48
# 240  경남함양군    528,788    588,379   4,752    593,131       -10.85
# 241  경남거창군    657,970    730,724   2,876    733,600       -10.31
# 242  경남합천군    723,434    729,945   1,420    731,365        -1.08
# 243     제주  6,269,014  6,619,951  18,709  6,638,659        -5.57
#
# [228 rows x 6 columns]

# %%
df_temp_3['자치단체'].str.slice(start=0, stop = 2)
# Out:
# 2      서울
# 3      서울
# 4      서울
# 5      서울
# 6      서울
#        ..
# 239    경남
# 240    경남
# 241    경남
# 242    경남
# 243    제주
# Name: 자치단체, Length: 228, dtype: object

# %%
df_temp_3['자치단체'].str.slice(start=2)
# Out:
# 2      종로구
# 3       중구
# 4      용산구
# 5      성동구
# 6      광진구
#       ...
# 239    산청군
# 240    함양군
# 241    거창군
# 242    합천군
# 243
# Name: 자치단체, Length: 228, dtype: object

# %%
df_temp_3['시도'] = df_temp_3['자치단체'].str.slice(start=0, stop = 2)
df_temp_3['시군구'] = df_temp_3['자치단체'].str.slice(start=2)
# Out:
# <ipython-input-155-ecef1da07c0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'] = df_temp_3['자치단체'].str.slice(start=0, stop = 2)
# <ipython-input-155-ecef1da07c0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시군구'] = df_temp_3['자치단체'].str.slice(start=2)

# %%
df_temp_3
# Out:
#       자치단체         세입         지출     순융자     통합재정규모 통합재정수지비율[당초]  시도  시군구
# 2    서울종로구    491,181    580,958   1,271    582,228       -15.64  서울  종로구
# 3     서울중구    493,300    587,593     462    588,055       -16.11  서울   중구
# 4    서울용산구    579,934    605,121   3,511    608,632        -4.72  서울  용산구
# 5    서울성동구    656,342    726,047     702    726,749        -9.69  서울  성동구
# 6    서울광진구    699,821    838,720   1,795    840,515       -16.74  서울  광진구
# ..     ...        ...        ...     ...        ...          ...  ..  ...
# 239  경남산청군    539,844    608,361   1,465    609,826       -11.48  경남  산청군
# 240  경남함양군    528,788    588,379   4,752    593,131       -10.85  경남  함양군
# 241  경남거창군    657,970    730,724   2,876    733,600       -10.31  경남  거창군
# 242  경남합천군    723,434    729,945   1,420    731,365        -1.08  경남  합천군
# 243     제주  6,269,014  6,619,951  18,709  6,638,659        -5.57  제주
#
# [228 rows x 8 columns]

# %%
df_temp_3.to_csv(path_dateset + savefile_name, index = False, encoding='utf-8-sig')

# %%
pd.read_csv(path_dateset + savefile_name)
# Out:
#       자치단체         세입         지출     순융자     통합재정규모  통합재정수지비율[당초]  시도  시군구
# 0    서울종로구    491,181    580,958   1,271    582,228        -15.64  서울  종로구
# 1     서울중구    493,300    587,593     462    588,055        -16.11  서울   중구
# 2    서울용산구    579,934    605,121   3,511    608,632         -4.72  서울  용산구
# 3    서울성동구    656,342    726,047     702    726,749         -9.69  서울  성동구
# 4    서울광진구    699,821    838,720   1,795    840,515        -16.74  서울  광진구
# ..     ...        ...        ...     ...        ...           ...  ..  ...
# 223  경남산청군    539,844    608,361   1,465    609,826        -11.48  경남  산청군
# 224  경남함양군    528,788    588,379   4,752    593,131        -10.85  경남  함양군
# 225  경남거창군    657,970    730,724   2,876    733,600        -10.31  경남  거창군
# 226  경남합천군    723,434    729,945   1,420    731,365         -1.08  경남  합천군
# 227     제주  6,269,014  6,619,951  18,709  6,638,659         -5.57  제주  NaN
#
# [228 rows x 8 columns]

# %%
path_dateset + savefile_name
# Out:
# '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/원본/통합재정수지비율당초자치단체(전처리)).csv'

# %%
print(savefile_name_1)
print(savefile_name_2)
print(savefile_name_3)
# Out:
# 원본/재정자립도당초자치단체(전처리)).csv
# 원본/재정자주도당초자치단체(전처리)).csv
# 원본/통합재정수지비율당초자치단체(전처리)).csv

# %% [markdown]
# ### 파일 합치기
# - 원본/재정자립도당초자치단체(전처리)).csv
# - 원본/재정자주도당초자치단체(전처리)).csv
# - 원본/통합재정수지비율당초자치단체(전처리)).csv

# %% [markdown]
# ---
# #### 데이터 샘플

# %%
er.Read_nrows(path_dateset + '전처리/재정자주도당초자치단체(전처리)).csv', 3)
# Out:
#     자치단체     자체수입    자주재원 자치단체 예산규모  재정자주도[당초]  시도  시군구
# 0  서울종로구  209,783  80,588   498,962      58.19  서울  종로구
# 1   서울중구  281,447  25,976   524,792      58.58  서울   중구
# 2  서울용산구  232,426  75,829   590,040      52.24  서울  용산구

# %%
er.Read_nrows(path_dateset + '전처리/재정자립도당초자치단체(전처리)).csv', 3)
# Out:
#     자치단체     자체수입 자치단체 예산규모  재정자립도[당초]  시도  시군구
# 0  서울종로구  209,783   498,962      42.04  서울  종로구
# 1   서울중구  281,447   524,792      53.63  서울   중구
# 2  서울용산구  232,426   590,040      39.39  서울  용산구

# %%
er.Read_nrows(path_dateset + '전처리/통합재정수지비율당초자치단체(전처리)).csv', 3)
# Out:
#     자치단체       세입       지출    순융자   통합재정규모  통합재정수지비율[당초]  시도  시군구
# 0  서울종로구  491,181  580,958  1,271  582,228        -15.64  서울  종로구
# 1   서울중구  493,300  587,593    462  588,055        -16.11  서울   중구
# 2  서울용산구  579,934  605,121  3,511  608,632         -4.72  서울  용산구

# %% [markdown]
# ---
# #### 데이터 읽기

# %%
 df1 = em.Read_File(path_dateset + '전처리/재정자주도당초자치단체(전처리)).csv')
 df1.head(2)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/전처리/재정자주도당초자치단체(전처리)).csv , encoding :  UTF-8-SIG
#     자치단체     자체수입    자주재원 자치단체 예산규모  재정자주도[당초]  시도  시군구
# 0  서울종로구  209,783  80,588   498,962      58.19  서울  종로구
# 1   서울중구  281,447  25,976   524,792      58.58  서울   중구

# %%
 df2 = em.Read_File(path_dateset + '전처리/재정자립도당초자치단체(전처리)).csv')
 df2.head(2)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/전처리/재정자립도당초자치단체(전처리)).csv , encoding :  UTF-8-SIG
#     자치단체     자체수입 자치단체 예산규모  재정자립도[당초]  시도  시군구
# 0  서울종로구  209,783   498,962      42.04  서울  종로구
# 1   서울중구  281,447   524,792      53.63  서울   중구

# %%
 df3 = em.Read_File(path_dateset + '전처리/통합재정수지비율당초자치단체(전처리)).csv')
 df3.head(2)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/전처리/통합재정수지비율당초자치단체(전처리)).csv , encoding :  UTF-8-SIG
#     자치단체       세입       지출    순융자   통합재정규모  통합재정수지비율[당초]  시도  시군구
# 0  서울종로구  491,181  580,958  1,271  582,228        -15.64  서울  종로구
# 1   서울중구  493,300  587,593    462  588,055        -16.11  서울   중구

# %%
df_1_2 = pd.merge(df1, df2[['자치단체', '재정자립도[당초]']], how='inner', on='자치단체')

# %%
df_1_2
# Out:
#       자치단체       자체수입       자주재원  자치단체 예산규모  재정자주도[당초]  시도  시군구  재정자립도[당초]
# 0    서울종로구    209,783     80,588    498,962      58.19  서울  종로구      42.04
# 1     서울중구    281,447     25,976    524,792      58.58  서울   중구      53.63
# 2    서울용산구    232,426     75,829    590,040      52.24  서울  용산구      39.39
# 3    서울성동구    212,385    137,733    704,153      49.72  서울  성동구      30.16
# 4    서울광진구    175,211    169,644    754,983      45.68  서울  광진구      23.21
# ..     ...        ...        ...        ...        ...  ..  ...        ...
# 223  경남산청군     54,342    277,114    583,622      56.79  경남  산청군       9.31
# 224  경남함양군     59,995    273,622    589,220      56.62  경남  함양군      10.18
# 225  경남거창군     59,368    345,180    747,367      54.13  경남  거창군       7.94
# 226  경남합천군     58,826    347,549    726,435      55.94  경남  합천군       8.10
# 227     제주  1,931,686  1,873,193  5,682,285      66.96  제주  NaN      33.99
#
# [228 rows x 8 columns]

# %%
df_1_2.isnull().sum()
# Out:
# 자치단체         0
# 자체수입         0
# 자주재원         0
# 자치단체 예산규모    0
# 재정자주도[당초]    0
# 시도           0
# 시군구          2
# 재정자립도[당초]    0
# dtype: int64

# %%
df_1_2['교부세비율'] = df_1_2['재정자주도[당초]'] - df_1_2['재정자립도[당초]']
df_1_2['국고보조금비율'] = 100 - df_1_2['재정자주도[당초]']

# %%
df_1_2
# Out:
#       자치단체       자체수입       자주재원  자치단체 예산규모  재정자주도[당초]  시도  시군구  재정자립도[당초]  \
# 0    서울종로구    209,783     80,588    498,962      58.19  서울  종로구      42.04
# 1     서울중구    281,447     25,976    524,792      58.58  서울   중구      53.63
# 2    서울용산구    232,426     75,829    590,040      52.24  서울  용산구      39.39
# 3    서울성동구    212,385    137,733    704,153      49.72  서울  성동구      30.16
# 4    서울광진구    175,211    169,644    754,983      45.68  서울  광진구      23.21
# ..     ...        ...        ...        ...        ...  ..  ...        ...
# 223  경남산청군     54,342    277,114    583,622      56.79  경남  산청군       9.31
# 224  경남함양군     59,995    273,622    589,220      56.62  경남  함양군      10.18
# 225  경남거창군     59,368    345,180    747,367      54.13  경남  거창군       7.94
# 226  경남합천군     58,826    347,549    726,435      55.94  경남  합천군       8.10
# 227     제주  1,931,686  1,873,193  5,682,285      66.96  제주  NaN      33.99
#
#      교부세비율  국고보조금비율
# 0    16.15    41.81
# 1     4.95    41.42
# ...

# %%
df_1_2 = pd.merge(df_1_2, df3[['자치단체', '세입', '지출', '순융자', '통합재정규모', '통합재정수지비율[당초]']], how='inner', on='자치단체')

# %%
df_1_2
# Out:
#       자치단체       자체수입       자주재원  자치단체 예산규모  재정자주도[당초]  시도  시군구  재정자립도[당초]  \
# 0    서울종로구    209,783     80,588    498,962      58.19  서울  종로구      42.04
# 1     서울중구    281,447     25,976    524,792      58.58  서울   중구      53.63
# 2    서울용산구    232,426     75,829    590,040      52.24  서울  용산구      39.39
# 3    서울성동구    212,385    137,733    704,153      49.72  서울  성동구      30.16
# 4    서울광진구    175,211    169,644    754,983      45.68  서울  광진구      23.21
# ..     ...        ...        ...        ...        ...  ..  ...        ...
# 223  경남산청군     54,342    277,114    583,622      56.79  경남  산청군       9.31
# 224  경남함양군     59,995    273,622    589,220      56.62  경남  함양군      10.18
# 225  경남거창군     59,368    345,180    747,367      54.13  경남  거창군       7.94
# 226  경남합천군     58,826    347,549    726,435      55.94  경남  합천군       8.10
# 227     제주  1,931,686  1,873,193  5,682,285      66.96  제주  NaN      33.99
#
# ...

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치단체          228 non-null    object
#  1   자체수입          228 non-null    int64
#  2   자주재원          228 non-null    int64
#  3   자치단체 예산규모     228 non-null    int64
#  4   재정자주도[당초]     228 non-null    float64
#  5   시도            228 non-null    object
#  6   시군구           226 non-null    object
#  7   재정자립도[당초]     228 non-null    float64
#  8   교부세비율         228 non-null    float64
#  9   국고보조금비율       228 non-null    float64
#  10  세입            228 non-null    int64
#  11  지출            228 non-null    int64
#  12  순융자           228 non-null    int64
#  13  통합재정규모        228 non-null    int64
#  14  통합재정수지비율[당초]  228 non-null    float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 26.8+ KB

# %%
df_1_2['자체수입'] = df_1_2['자체수입'].str.replace(',', '').astype(int)
df_1_2['자주재원'] = df_1_2['자주재원'].str.replace(',', '').astype(int)
df_1_2['자치단체 예산규모'] = df_1_2['자치단체 예산규모'].str.replace(',', '').astype(int)
df_1_2['세입'] = df_1_2['세입'].str.replace(',', '').astype(int)
df_1_2['지출'] = df_1_2['지출'].str.replace(',', '').astype(int)
df_1_2['순융자'] = df_1_2['순융자'].str.replace(',', '').astype(int)
df_1_2['통합재정규모'] = df_1_2['통합재정규모'].str.replace(',', '').astype(int)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치단체          228 non-null    object
#  1   자체수입          228 non-null    int64
#  2   자주재원          228 non-null    int64
#  3   자치단체 예산규모     228 non-null    int64
#  4   재정자주도[당초]     228 non-null    float64
#  5   시도            228 non-null    object
#  6   시군구           226 non-null    object
#  7   재정자립도[당초]     228 non-null    float64
#  8   교부세비율         228 non-null    float64
#  9   국고보조금비율       228 non-null    float64
#  10  세입            228 non-null    int64
#  11  지출            228 non-null    int64
#  12  순융자           228 non-null    int64
#  13  통합재정규모        228 non-null    int64
#  14  통합재정수지비율[당초]  228 non-null    float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 26.8+ KB

# %%
df_temp.shape
# Out:
# (228, 15)

# %%
df_1_2.to_csv(path_dateset + '전처리/재정자주도_자립도_통합재정수지비율(병합).csv', index = False, encoding='utf-8-sig')

# %% [markdown]
# ### 저장 데이터 불러오기

# %%
df_temp_1 = pd.read_csv(path_dateset + '전처리/재정자주도_자립도_통합재정수지비율(병합).csv')
df_temp_1.head(3)
# Out:
#     자치단체    자체수입   자주재원  자치단체 예산규모  재정자주도[당초]  시도  시군구  재정자립도[당초]  교부세비율  \
# 0  서울종로구  209783  80588     498962      58.19  서울  종로구      42.04  16.15
# 1   서울중구  281447  25976     524792      58.58  서울   중구      53.63   4.95
# 2  서울용산구  232426  75829     590040      52.24  서울  용산구      39.39  12.85
#
#    국고보조금비율      세입      지출   순융자  통합재정규모  통합재정수지비율[당초]
# 0    41.81  491181  580958  1271  582228        -15.64
# 1    41.42  493300  587593   462  588055        -16.11
# 2    47.76  579934  605121  3511  608632         -4.72

# %%
df_temp_2 = pd.read_csv(path_dateset + '전처리/시군구_전처리_보안등,주차장,버스정류장등(12개)/시군구_보안등,주차장,버스정류장등(12개)_데이터셋.csv')
df_temp_2.head(3)
# Out:
#         시도  시군구   보안등_개수  주차장_수  전통시장_수  은행환전소  CCTV개수   평균소득금액  체육시설수  \
# 0  강원특별자치도  강릉시  12252.0  120.0     8.0   20.0  1959.0  35015.0  433.0
# 1  강원특별자치도  고성군   1827.0   23.0     2.0    2.0   503.0  31793.0   95.0
# 2  강원특별자치도  동해시   4549.0   24.0     5.0   16.0   361.0  35198.0  179.0
#
#     음식점_수  관광지_수  대규모점포_수  시군구별_도시내공원  시군구별_버스정류장
# 0  4803.0  467.0     10.0        29.0     40.0000
# 1   728.0  199.0      0.0        18.0    576.8125
# 2  1722.0  105.0      3.0        31.0    393.0000

# %%
df_temp_1['시도'].value_counts()
# Out:
# 시도
# 경기도        31
# 서울특별시      25
# 전라남도       22
# 경상북도       22
# 강원특별자치도    18
# 경상남도       18
# 부산광역시      16
# 충청남도       15
# 전북특별자치도    14
# 충청북도       11
# 인천광역시      10
# 대구광역시       9
# 대전광역시       5
# 광주광역시       5
# 울산광역시       5
# 세종특별자치시     1
# 제주특별자치도     1
# Name: count, dtype: int64

# %%
df_temp_2['시도'].value_counts()
# Out:
# 시도
# 경기도        31
# 서울특별시      25
# 전라남도       22
# 경상북도       22
# 강원특별자치도    18
# 경상남도       18
# 부산광역시      16
# 충청남도       15
# 전북특별자치도    14
# 충청북도       11
# 인천광역시      10
# 대구광역시       9
# 대전광역시       5
# 광주광역시       5
# 울산광역시       5
# 세종특별자치시     1
# 제주특별자치도     1
# Name: count, dtype: int64

# %%
df_temp_1['시도'][df_temp_1['시도'] == '경기'] = '경기도'
# Out:
# <ipython-input-25-1f646a91f953>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_1['시도'][df_temp_1['시도'] == '경기'] = '경기도'
# <ipython-input-25-1f646a91f953>:1: SettingWithCopyWarning:
# ...

# %%
_val_before = ['경기', '서울', '전남', '경북', '강원', '경남', '부산', '충남', '전북', '충북', '인천', '대구', '광주', '대전', '울산', '세종', '제주']
_val_after = ['경기도', '서울특별시', '전라남도', '경상북도', '강원특별자치도', '경상남도', '부산광역시', '충청남도', '전북특별자치도', '충청북도', '인천광역시', '대구광역시', '대전광역시', '광주광역시', '울산광역시', '세종특별자치시', '제주특별자치도']

for i in range(len(_val_before)):
  # print(_val_before[i])
  df_temp_1['시도'][df_temp_1['시도'] == _val_before[i]] = _val_after[i]
# Out:
# <ipython-input-27-efad26198616>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_1['시도'][df_temp_1['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-27-efad26198616>:6: SettingWithCopyWarning:
# ...

# %%
df_temp_1.head(3)
# Out:
#     자치단체    자체수입   자주재원  자치단체 예산규모  재정자주도[당초]     시도  시군구  재정자립도[당초]  교부세비율  \
# 0  서울종로구  209783  80588     498962      58.19  서울특별시  종로구      42.04  16.15
# 1   서울중구  281447  25976     524792      58.58  서울특별시   중구      53.63   4.95
# 2  서울용산구  232426  75829     590040      52.24  서울특별시  용산구      39.39  12.85
#
#    국고보조금비율      세입      지출   순융자  통합재정규모  통합재정수지비율[당초]
# 0    41.81  491181  580958  1271  582228        -15.64
# 1    41.42  493300  587593   462  588055        -16.11
# 2    47.76  579934  605121  3511  608632         -4.72

# %%
df_temp_1.to_csv(path_dateset + '전처리/재정자주도_자립도_통합재정수지비율(병합).csv', index = False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dc1d05a4ca5a> in <cell line: 1>()
# ----> 1 df_temp_1.to_csv(path_dateset + '전처리/재정자주도_자립도_통합재정수지비율(병합).csv', index = False, encoding='utf-8-sig')
#
# NameError: name 'df_temp_1' is not defined

# %%
df_temp_1 = pd.read_csv(path_dateset + '전처리/재정자주도_자립도_통합재정수지비율(병합).csv')

# %%
df_temp_1.head(5)
# Out:
#     자치단체    자체수입    자주재원  자치단체 예산규모  재정자주도[당초]     시도  시군구  재정자립도[당초]  교부세비율  \
# 0  서울종로구  209783   80588     498962      58.19  서울특별시  종로구      42.04  16.15
# 1   서울중구  281447   25976     524792      58.58  서울특별시   중구      53.63   4.95
# 2  서울용산구  232426   75829     590040      52.24  서울특별시  용산구      39.39  12.85
# 3  서울성동구  212385  137733     704153      49.72  서울특별시  성동구      30.16  19.56
# 4  서울광진구  175211  169644     754983      45.68  서울특별시  광진구      23.21  22.47
#
#    국고보조금비율      세입      지출   순융자  통합재정규모  통합재정수지비율[당초]
# 0    41.81  491181  580958  1271  582228        -15.64
# 1    41.42  493300  587593   462  588055        -16.11
# 2    47.76  579934  605121  3511  608632         -4.72
# 3    50.28  656342  726047   702  726749         -9.69
# 4    54.32  699821  838720  1795  840515        -16.74

# %%
df_temp_1.shape
# Out:
# (228, 15)

# %%
import plotly.graph_objects as go
import plotly.express as px

sort_val = '교부세비율'
df_1 = df_temp_1.sort_values(by = sort_val, ascending = False).head(20)   # 상위20
df_2 = df_temp_1.sort_values(by = sort_val, ascending = True).head(20)    # 하위20

df_1[sort_val] = df_1[sort_val].apply(lambda x: round(x, 2))
df_2[sort_val] = df_2[sort_val].apply(lambda x: round(x, 2))
# ===========================================================

# 그라데이션 색상 생성
values = df_1[sort_val]
colorscale = px.colors.sequential.Viridis
norm_values = (values - values.min()) / (values.max() - values.min())
colors = [colorscale[int(v * (len(colorscale) - 1))] for v in norm_values]

# 라인 플롯
fig1 = go.Figure()
fig1.add_trace(
    go.Scatter(
        x=df_1['자치단체'],
        y=df_1[sort_val],
        mode='lines+markers',
        line=dict(
            color='lightgrey',
            width=2
        ),
        marker=dict(
            color=colors,
            size=10,
            line=dict(
                color='white',
                width=1
            )
        )
    )
)

# 라인 플롯에 화살표와 값 추가
for i in range(len(df_1)):
    fig1.add_annotation(
        x=df_1['자치단체'].iloc[i],
        y=df_1[sort_val].iloc[i],
        text=f'{df_1[sort_val].iloc[i]}%',
        showarrow=False,
        yshift=10
    )

fig1.update_layout(
    title='자치단체별 ' + sort_val + ' (상위20) 비교',
    xaxis_title='자치단체',
    yaxis_title=sort_val,
    font=dict(family='Malgun Gothic'),
    showlegend=False
)

# ===========================================================
# 바 플롯
fig2 = go.Figure()
fig2.add_trace(
    go.Bar(
        x=df_2['자치단체'],
        y=df_2[sort_val],
        marker=dict(
            color=df_2[sort_val],
            colorscale='Viridis'
        ),
        text=df_2[sort_val].apply(lambda x: f'{x:.2f}%'),
        textposition='outside',
        textfont=dict(size=12)
    )
)

fig2.update_layout(
    title='자치단체별 ' + sort_val + ' (하위20) 비교',
    xaxis_title='자치단체',
    yaxis_title='sort_val',
    font=dict(family='Malgun Gothic'),
    showlegend=False
)

# ===========================================================
# 그래프 표시
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
