# %% [markdown]
# ## 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## 필요 라이브러리 임포트
# - 추가 사용자 정의함수 불러오기

# %%
# 라이브러리 임포트
import os
import numpy as np
import pandas as pd
import chardet

import time

import folium

# 사용자 정의함수 경로 설정
import sys
# sys.path.append("H:/내 드라이브/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")
sys.path.append("/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/Source/_Custom_Function")

# 사용자 정의함수 불러오기
import ExcelFile_Merge as em
import ExcelFile_Read as er
import ExcelFile_EDA as ee

import dataset_function as ds_f
import folium_function as fl_f
import plot_function as pl_f

# %%
# 나의 루트 경로 설정
path_dateset = '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/'

# %%
file_name_1 = '전처리/시군구_인구밀도(전처리).csv'

savefile_name_1 = '전처리/시군구_인구밀도(전처리)_2.csv'

# %% [markdown]
# ## 전처리 할 파일 선택

# %%
file_name = file_name_1
savefile_name = savefile_name_1

# %%
df_temp = em.Read_File(path_dateset + file_name)
# Out:
# read_file - file_path :  /gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/전처리/시군구_인구밀도(전처리).csv , encoding :  EUC-KR

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   시도	시군구	총인구수(2023년)	면적	인구밀도  227 non-null    object
# dtypes: object(1)
# memory usage: 1.9+ KB

# %%
df_temp
# Out:
#                         시도\t시군구\t총인구수(2023년)\t면적\t인구밀도
# 0    강원특별자치도\t강릉시\t209439 \t1040827452 \t0.0002012236
# 1      강원특별자치도\t고성군\t27305 \t660766514 \t0.0000413232
# 2      강원특별자치도\t동해시\t88625 \t180307717 \t0.0004915208
# 3     강원특별자치도\t삼척시\t62651 \t1187836727 \t0.0000527438
# 4      강원특별자치도\t속초시\t82054 \t105753667 \t0.0007758974
# ..                                                 ...
# 222      충청북도\t제천시\t130194 \t882770985 \t0.0001474833
# 223        충청북도\t증평군\t37484 \t81802888 \t0.0004582234
# 224       충청북도\t진천군\t86254 \t407384400 \t0.0002117263
# 225      충청북도\t청주시\t852189 \t941054215 \t0.0009055684
# 226      충청북도\t충주시\t207778 \t983257123 \t0.0002113160
#
# [227 rows x 1 columns]

# %%
# 데이터프레임의 컬럼을 탭으로 분리
df_temp[['시도', '시군구', '총인구수(2023년)', '면적', '인구밀도']] = df_temp[df_temp.columns[0]].str.split('\t', expand=True)

# df[['지역명', '코드1', '코드2', '코드3']] = df[df.columns[0]].str.split('W', expand=True)

# %%
df_temp = df_temp.iloc[:, 1:]
df_temp
# Out:
#           시도  시군구 총인구수(2023년)           면적           인구밀도
# 0    강원특별자치도  강릉시     209439   1040827452   0.0002012236
# 1    강원특별자치도  고성군      27305    660766514   0.0000413232
# 2    강원특별자치도  동해시      88625    180307717   0.0004915208
# 3    강원특별자치도  삼척시      62651   1187836727   0.0000527438
# 4    강원특별자치도  속초시      82054    105753667   0.0007758974
# ..       ...  ...         ...          ...            ...
# 222     충청북도  제천시     130194    882770985   0.0001474833
# 223     충청북도  증평군      37484     81802888   0.0004582234
# 224     충청북도  진천군      86254    407384400   0.0002117263
# 225     충청북도  청주시     852189    941054215   0.0009055684
# 226     충청북도  충주시     207778    983257123   0.0002113160
#
# [227 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_temp.to_csv(path_dateset + '전처리/시군구_인구밀도(전처리)_dzp.csv', index = False, encoding='utf-8-sig')

# %%
pd.read_csv(path_dateset + '전처리/시군구_인구밀도(전처리)_dzp.csv')
# Out:
#           시도      시군구  총인구수(2023년)          면적      인구밀도
# 0    강원특별자치도      강릉시       209439  1040827452  0.000201
# 1    강원특별자치도      고성군        27305   660766514  0.000041
# 2    강원특별자치도      동해시        88625   180307717  0.000492
# 3    강원특별자치도      삼척시        62651  1187836727  0.000053
# 4    강원특별자치도      속초시        82054   105753667  0.000776
# 5    강원특별자치도      양구군        21056   661991727  0.000032
# 6    강원특별자치도      양양군        27710   629777062  0.000044
# 7    강원특별자치도      영월군        37332  1127407715  0.000033
# 8    강원특별자치도      원주시       361503   868285191  0.000416
# 9    강원특별자치도      인제군        32020  1646197571  0.000019
# 10   강원특별자치도      정선군        34202  1219781214  0.000028
# 11   강원특별자치도      철원군        41448   890129727  0.000047
# 12   강원특별자치도      춘천시       286426  1116415790  0.000257
# 13   강원특별자치도      태백시        38702   303438428  0.000128
# 14   강원특별자치도      평창군        40659  1464257647  0.000028
# 15   강원특별자치도      홍천군        67309  1820572726  0.000037
# 16   강원특별자치도      화천군        23007   909094533  0.000025
# 17   강원특별자치도      횡성군        46359   998002199  0.000046
# 18       경기도      가평군        62302   842821966  0.000074
# 19       경기도      고양시      1074907   268126897  0.004009
# 20       경기도      과천시        81000    35871399  0.002258
# 21       경기도      광명시       280197    38521193  0.007274
# 22       경기도      광주시       391377   430988337  0.000908
# 23       경기도      구리시       187093    33338735  0.005612
# 24       경기도      군포시       261229    36418522  0.007173
# 25       경기도      김포시       486172   276596404  0.001758
# 26       경기도     남양주시       732265   458129777  0.001598
# 27       경기도     동두천시        88626    95673631  0.000926
# 28       경기도      부천시       779968    53458066  0.014590
# 29       경기도      성남시       919747   141630278  0.006494
# 30       경기도      수원시      1197257   121099865  0.009887
# 31       경기도      시흥시       519715   139936378  0.003714
# 32       경기도      안산시       629308   156466886  0.004022
# 33       경기도      안성시       189034   553508056  0.000342
# 34       경기도      안양시       544660    58500757  0.009310
# 35       경기도      양주시       268026   310487150  0.000863
# 36       경기도      양평군       125238   877819526  0.000143
# 37       경기도      여주시       114412   608207922  0.000188
# 38       경기도      연천군        41584   677938351  0.000061
# 39       경기도      오산시       229656    42691583  0.005379
# 40       경기도      용인시      1075566   591254915  0.001819
# 41       경기도      의왕시       158870    54031240  0.002940
# 42       경기도     의정부시       464213    81548718  0.005692
# 43       경기도      이천시       222098   461464926  0.000481
# 44       경기도      파주시       497753   673955430  0.000739
# 45       경기도      평택시       591022   458448418  0.001289
# 46       경기도      포천시       143323   827165745  0.000173
# 47       경기도      하남시       329861    92985347  0.003547
# 48       경기도      화성시       944342   700641503  0.001348
# 49      경상남도      거제시       234038   403875204  0.000579
# 50      경상남도      거창군        60047   803956581  0.000075
# 51      경상남도      고성군        49468   518022858  0.000095
# 52      경상남도      김해시       533659   463545853  0.001151
# 53      경상남도      남해군        40780   357780914  0.000114
# 111    부산광역시       남구       254185    26824059  0.009476
# 112    부산광역시       동구        87792    10121482  0.008674
# 113    부산광역시      동래구       270815    16630862  0.016284
# 114    부산광역시     부산진구       359508    29666182  0.012118
# 115    부산광역시       북구       273596    39374075  0.006949
# 116    부산광역시      사상구       202932    36104624  0.005621
# 117    부산광역시      사하구       297831    41784929  0.007128
# 118    부산광역시       서구       104089    13972027  0.007450
# 119    부산광역시      수영구       174518    10217448  0.017080
# 120    부산광역시      연제구       205766    12105987  0.016997
# 121    부산광역시      영도구       106548    14200497  0.007503
# 122    부산광역시       중구        38619     3012982  0.012818
# 123    부산광역시     해운대구       380448    51522722  0.007384
# 124    서울특별시      강남구       544873    39497597  0.013795
# 125    서울특별시      강동구       459167    24590383  0.018673
# 126    서울특별시      강북구       288113    23600408  0.012208
# 127    서울특별시      강서구       563058    41451954  0.013583
# 128    서울특별시      관악구       481956    29568369  0.016300
# 129    서울특별시      광진구       335554    17062820  0.019666
# 130    서울특별시      구로구       392405    20122908  0.019500
# 131    서울특별시      금천구       227481    13020528  0.017471
# 132    서울특별시      노원구       498213    35439122  0.014058
# 133    서울특별시      도봉구       306948    20651010  0.014864
# 134    서울특별시     동대문구       341149    14215912  0.023998
# 135    서울특별시      동작구       378769    16356863  0.023157
# 136    서울특별시      마포구       363697    23853966  0.015247
# 137    서울특별시     서대문구       306231    17626320  0.017374
# 138    서울특별시      서초구       407664    46965959  0.008680
# 139    서울특별시      성동구       277361    16820149  0.016490
# 140    서울특별시      성북구       425602    24577918  0.017316
# 141    서울특별시      송파구       654166    33876575  0.019310
# 142    서울특별시      양천구       436028    17406040  0.025050
# 143    서울특별시     영등포구       374794    24551194  0.015266
# 144    서울특별시      용산구       213151    21867577  0.009747
# 145    서울특별시      은평구       466770    29710154  0.015711
# 146    서울특별시      종로구       139417    23913223  0.005830
# 147    서울특별시       중구       121312     9959947  0.012180
# 148    서울특별시      중랑구       382155    18497135  0.020660
# 149    울산광역시       남구       307232    74019618  0.004151
# 150    울산광역시       동구       152287    36074884  0.004221
# 151    울산광역시       북구       216477   157351542  0.001376
# 152    울산광역시      울주군       218997   758377003  0.000289
# 153    울산광역시       중구       208668    37004028  0.005639
# 154    인천광역시      강화군        69005   411407321  0.000168
# 155    인천광역시      계양구       280266    45565891  0.006151
# 156    인천광역시      남동구       492415    57453407  0.008571
# 157    인천광역시       동구        59482     7247383  0.008207
# 158    인천광역시     미추홀구       405995    24838672  0.016345
# 159    인천광역시      부평구       494138    32005409  0.015439
# 160    인천광역시       서구       624358   119056594  0.005244
# 161    인천광역시      연수구       392416    56190621  0.006984
# 162    인천광역시      옹진군        20377   172949620  0.000118
# 163    인천광역시       중구       158958   140379853  0.001132
# 164     전라남도      강진군        32722   500897659  0.000065
# 165     전라남도      고흥군        61113   807174091  0.000076
# 166     전라남도      곡성군        26905   547292828  0.000049
# 167     전라남도      광양시       152666   464863826  0.000328
# 224     충청북도      진천군        86254   407384400  0.000212
# 225     충청북도      청주시       852189   941054215  0.000906
# 226     충청북도      충주시       207778   983257123  0.000211

# %%
df_temp['시도'] = df_temp['자치단체명'].str.slice(start=0, stop = 2)
df_temp['시군구'] = df_temp['자치단체명'].str.slice(start=2)

# %%
df_temp.head(3)
# Out:
#    No 지역명   자치단체코드  자치단체명    도로  대중교통･ 물류등기타    합계  \
# 0   1  서울  1100000   서울본청  1.94         6.93  8.87
# 1   2  서울  1111000  서울종로구  1.79         6.19  7.98
# 2   3  서울  1112000   서울중구  0.86         1.75  2.61
#
#                                                  URL  시도  시군구
# 0  https://news.seoul.go.kr/gov/archives/554900?l...  서울   본청
# 1  https://www.jongno.go.kr/portal/bbs/selectBoar...  서울  종로구
# 2  https://www.junggu.seoul.kr/content.do?cmsid=1...  서울   중구

# %%
_columns = ['시도', '시군구', '도로', '대중교통･ 물류등기타', '합계']
df_temp_2 = df_temp[_columns]

# %%
df_temp_2.shape
# Out:
# (243, 5)

# %%
df_temp_2.head(3)
# Out:
#    시도  시군구    도로  대중교통･ 물류등기타    합계
# 0  서울   본청  1.94         6.93  8.87
# 1  서울  종로구  1.79         6.19  7.98
# 2  서울   중구  0.86         1.75  2.61

# %%
cond1 = df_temp_2['시군구'].str.contains('본청')
cond2 = df_temp_2['시도'].isin(['세종', '제주'])
df_temp_3 = df_temp_2[~(cond1 & ~cond2)]
df_temp_3
# Out:
#      시도  시군구    도로  대중교통･ 물류등기타    합계
# 1    서울  종로구  1.79         6.19  7.98
# 2    서울   중구  0.86         1.75  2.61
# 3    서울  용산구  2.33         0.47  2.80
# 4    서울  성동구  0.78         2.15  2.93
# 5    서울  광진구  1.76         6.32  8.08
# ..   ..  ...   ...          ...   ...
# 238  경남  산청군  2.42         1.21  3.63
# 239  경남  함양군  1.85         1.74  3.59
# 240  경남  거창군  2.15         2.32  4.47
# 241  경남  합천군  2.93         1.57  4.50
# 242  제주   본청  2.66         3.79  6.45
#
# [228 rows x 5 columns]

# %%
_val_before = ['경기', '서울', '전남', '경북', '강원', '경남', '부산', '충남', '전북', '충북', '인천', '대구', '광주', '대전', '울산', '세종', '제주']
_val_after = ['경기도', '서울특별시', '전라남도', '경상북도', '강원특별자치도', '경상남도', '부산광역시', '충청남도', '전북특별자치도', '충청북도', '인천광역시', '대구광역시', '대전광역시', '광주광역시', '울산광역시', '세종특별자치시', '제주특별자치도']

for i in range(len(_val_before)):
  # print(_val_before[i])
  df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# Out:
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]
# <ipython-input-50-74c1c0829066>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시도'][df_temp_3['시도'] == _val_before[i]] = _val_after[i]

# %%
df_temp_3.head(5)
# Out:
#       시도  시군구    도로  대중교통･ 물류등기타    합계
# 1  서울특별시  종로구  1.79         6.19  7.98
# 2  서울특별시   중구  0.86         1.75  2.61
# 3  서울특별시  용산구  2.33         0.47  2.80
# 4  서울특별시  성동구  0.78         2.15  2.93
# 5  서울특별시  광진구  1.76         6.32  8.08

# %%
df_temp_3['시군구'][df_temp_3['시도'].isin(['세종특별자치시'])] = '세종특별자치시'
df_temp_3['시군구'][df_temp_3['시도'].isin(['제주특별자치도'])] = '제주특별자치도'
# Out:
# <ipython-input-56-10751ebeb9b1>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['세종특별자치시'])] = '세종특별자치시'
# <ipython-input-56-10751ebeb9b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['세종특별자치시'])] = '세종특별자치시'
# <ipython-input-56-10751ebeb9b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['세종특별자치시'])] = '세종특별자치시'
# <ipython-input-56-10751ebeb9b1>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['제주특별자치도'])] = '제주특별자치도'
# <ipython-input-56-10751ebeb9b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['제주특별자치도'])] = '제주특별자치도'
# <ipython-input-56-10751ebeb9b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3['시군구'][df_temp_3['시도'].isin(['제주특별자치도'])] = '제주특별자치도'

# %%
df_temp_3[df_temp_3['시도'].isin(['세종특별자치시', '제주특별자치도'])]
# Out:
#           시도      시군구    도로  대중교통･ 물류등기타    합계
# 82   세종특별자치시  세종특별자치시  1.20         5.32  6.52
# 242  제주특별자치도  제주특별자치도  2.66         3.79  6.45

# %%
df_temp_3.rename(columns = {'대중교통･ 물류등기타' : '대중교통_물류등기타'}, inplace = True)
# Out:
# <ipython-input-58-44a5da71031e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_3.rename(columns = {'대중교통･ 물류등기타' : '대중교통_물류등기타'}, inplace = True)

# %%
df_temp_3.head(5)
# Out:
#       시도  시군구    도로  대중교통_물류등기타    합계
# 1  서울특별시  종로구  1.79        6.19  7.98
# 2  서울특별시   중구  0.86        1.75  2.61
# 3  서울특별시  용산구  2.33        0.47  2.80
# 4  서울특별시  성동구  0.78        2.15  2.93
# 5  서울특별시  광진구  1.76        6.32  8.08

# %%
df_temp_3.shape
# Out:
# (228, 5)

# %%
path_dateset + savefile_name
# Out:
# '/gdrive/MyDrive/_Projects/재정데이터분석_미니프로젝트/DataSet/우리 지자체 예산서(완성)v1.0(전처리)).csv'

# %%
df_temp_3.to_csv(path_dateset + savefile_name, index = False, encoding='utf-8-sig')

# %%
pd.read_csv(path_dateset + savefile_name)
# Out:
#           시도      시군구    도로  대중교통_물류등기타    합계
# 0      서울특별시      종로구  1.79        6.19  7.98
# 1      서울특별시       중구  0.86        1.75  2.61
# 2      서울특별시      용산구  2.33        0.47  2.80
# 3      서울특별시      성동구  0.78        2.15  2.93
# 4      서울특별시      광진구  1.76        6.32  8.08
# ..       ...      ...   ...         ...   ...
# 223     경상남도      산청군  2.42        1.21  3.63
# 224     경상남도      함양군  1.85        1.74  3.59
# 225     경상남도      거창군  2.15        2.32  4.47
# 226     경상남도      합천군  2.93        1.57  4.50
# 227  제주특별자치도  제주특별자치도  2.66        3.79  6.45
#
# [228 rows x 5 columns]
